# %% [markdown]
# <a href="https://colab.research.google.com/github/shaheer-baig43/Python-Projects/blob/main/MadLibs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mad libs Python Project

# %%
#inputs
character = input('Enter a boy name: ')
place = input('Enter any place: (e.g. beach, library )')
object = input('Enter any object: ')

#story
print('\n The Story Generated by your input values')

print(f'Once upon a time, {character} was walking through {place} when he stumbled upon the {object}. Little did they know, this discovery would change their life forever')
# Out:
# Enter a boy name: shaheer
# Enter any place: (e.g. beach, library )room
# Enter any object: phonr
#
#  The Story Generated by your input values
# Once upon a time, shaheer was walking through room when he stumbled upon the phonr. Little did they know, this discovery would change their life forever
